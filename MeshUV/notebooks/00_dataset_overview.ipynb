# %% [markdown]
# # Dataset Overview — MeshUV-TD-PseudoGT
# 只读可视化(不触发 Teacher 计算, 不修改数据)。改 `DATASET_ROOT` 切换
# pilot / 正式 dataset / 未来 model run。

# %%
# %matplotlib inline
import sys, os
sys.path.insert(0, os.path.abspath("../src"))
from meshuv.visualization import *
import matplotlib.pyplot as plt

# 可切换: "datasets/pilot/TexVerse-1K-16" / "datasets/processed/MeshUV-TD-PseudoGT-MVP-v0"
DATASET_ROOT = "datasets/processed/MeshUV-TD-PseudoGT-MVP-v0"
root = resolve_root(DATASET_ROOT)
reports = load_reports(root) if root else {}
index = load_index(root) if root else []
print(f"accepted 对象: {len(index)}")
# Out:
# [缺失] processing_yield: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/processing_yield.json
# [缺失] pilot_summary: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/pilot_summary.json
# [缺失] rejection_summary: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/rejection_summary.json
# [缺失] rejection_report: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/rejection_report.json
# [缺失] splits: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/splits.json
# [缺失] run_manifest: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/run_manifest.json
# [缺失] dataset_index.jsonl: /root/youjiaZhang/PartUV/MeshUV/datasets/processed/MeshUV-TD-PseudoGT-MVP-v0/dataset_index.jsonl
# accepted 对象: 0

# %% [markdown]
# ## 1. 处理漏斗与拒绝分类

# %%
plot_funnel(reports); plt.show()
plot_rejections(reports); plt.show()
# Out:
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26080 (\N{CJK UNIFIED IDEOGRAPH-65E0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25253 (\N{CJK UNIFIED IDEOGRAPH-62A5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 2. 标签与耗时分布(抽样)

# %%
stats = scan_label_stats(root, index) if root else {}
plot_label_distributions(stats); plt.show()
# Out:
# /root/youjiaZhang/PartUV/MeshUV/src/meshuv/visualization/plots.py:82: UserWarning: Glyph 26080 (\N{CJK UNIFIED IDEOGRAPH-65E0}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /root/youjiaZhang/PartUV/MeshUV/src/meshuv/visualization/plots.py:82: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /root/youjiaZhang/PartUV/MeshUV/src/meshuv/visualization/plots.py:82: UserWarning: Glyph 25454 (\N{CJK UNIFIED IDEOGRAPH-636E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25454 (\N{CJK UNIFIED IDEOGRAPH-636E}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# ## 3. splits

# %%
plot_splits(reports); plt.show()
# Out:
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26500 (\N{CJK UNIFIED IDEOGRAPH-6784}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23436 (\N{CJK UNIFIED IDEOGRAPH-5B8C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/geomae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
